# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **MOIDEEN MUZHAMIL**</br>
# Data Engineer

# %% [markdown]
# _I am interested in data science because, I love working with data and I have a very good background in mathematics and also I am a good story teller. Data science is very interesting and there is huge scope for it, which is another reason why I chose data science._

# %% [markdown]
# ### This code will add two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# This is horizontal rule example
# ***
# Horizontal rule is shown
# -  bulleted list
# -  bulleted list
# -  bulleted list
# ***
# 1. numbered list
# 1. numbered list
# 1. numbered list
# # Table
#
# Name| Age| Salary|
# ----| ---| ------|
# aaaa| 20| 30000|
# bbbb| 21| 40000|
# cccc| 22| 50000|
#
# # hyperlink
# __[youtube](https://www.youtube.com/)__
#
#
#
# ![Screenshot (9).png](attachment:624879ce-f8e2-4e40-8339-4b5698c19406.png)
#
# `num=[1,2,3]`
#
# ``` Python
# array=[v1,v2,v3]
# ```
# >This is blocked quote
#
# <blockquote> this is blocked quote</blockquote>
#
# ~This is strike text~
